# %% [markdown]
# <a href="https://colab.research.google.com/github/pheonix-01/DL-Practical-Labs/blob/main/P01L02_Central_Limit_Theorem_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# For reproducible results
np.random.seed(42)

# Simulation parameters
num_samples = 1000       # Number of samples
sample_size = 30         # Size of each sample

# Generate samples from Uniform(0, 1)
samples = np.random.uniform(low=0, high=1, size=(num_samples, sample_size))

# Compute mean of each sample
sample_means = samples.mean(axis=1)

# Plot histogram of sample means
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.75)
plt.title('Central Limit Theorem: Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
