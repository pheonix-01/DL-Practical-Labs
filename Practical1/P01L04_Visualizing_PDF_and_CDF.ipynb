# %% [markdown]
# <a href="https://colab.research.google.com/github/pheonix-01/DL-Practical-Labs/blob/main/P01L04_Visualizing_PDF_and_CDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Visualizing PDF and CDF
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define range of x values
x = np.linspace(-4, 4, 1000)

# Mean and standard deviation
mu = 0
sigma = 1

# Calculate PDF and CDF
pdf = norm.pdf(x, loc=mu, scale=sigma)
cdf = norm.cdf(x, loc=mu, scale=sigma)

# Plot
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# PDF Plot
axs[0].plot(x, pdf, color='blue', label='PDF')
axs[0].set_title('Normal Distribution - PDF')
axs[0].set_xlabel('x')
axs[0].set_ylabel('Density')
axs[0].grid(True)
axs[0].legend()

# CDF Plot
axs[1].plot(x, cdf, color='green', label='CDF')
axs[1].set_title('Normal Distribution - CDF')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Cumulative Probability')
axs[1].grid(True)
axs[1].legend()

# Show plot
plt.tight_layout()
plt.show()
